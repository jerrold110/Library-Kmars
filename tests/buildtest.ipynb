# %%
import numpy as np
from sklearn.datasets import make_blobs

n_samples = 1500
random_state = 170
X, y = make_blobs(n_samples=n_samples, random_state=random_state)

import matplotlib.pyplot as plt

plt.scatter(X[:, 0], X[:, 1])
plt.title("Mixture of Gaussian Blobs")
plt.suptitle("Ground truth clusters").set_y(0.95)
plt.show()

# %%
# path management
import os
base_directory = os.path.dirname(os.getcwd())

import sys
sys.path.append(f"{base_directory}/src")

# %%
from kmars import KMeansEuclidean
km = KMeansEuclidean(3)
km.fit(X)
# Out:
# KMeans base class inheritance for __init__ of base class successful
# KMeansEuclidean object creation successful
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 from kmars import KMeansEuclidean
#       2 km = KMeansEuclidean(3)
# ----> 3 km.fit(X)
#
# File c:\Extra_folder_1\git_folder\Library-Kmars/src\kmars\kmeans_euclidean.py:140, in KMeansEuclidean.fit(self, X)
#     138     initial_centroids = self._init_random(X, self.n_clusters)
#     139 elif self._init == "kmeans++":
# --> 140     initial_centroids = self._init_kmeansplusplus(X, self._n_clusters)
#     141 else:
#     142     raise TypeError("The init variable %s is invalid ",(self._init))
#
# File c:\Extra_folder_1\git_folder\Library-Kmars/src\kmars\kmeans_euclidean.py:60, in KMeansEuclidean._init_kmeansplusplus(self, X, seed)
#      58     candidate_centroids = np.delete(candidate_centroids, next_centroid_ind, 0)
#      59 # Calculate SSE of the selected candidate centroids
# ---> 60 nearest_centroids = self._get_nearest_centroids(X, candidate_centroids)
#      61 sse = self._sse_error(X, candidate_centroids, nearest_centroids)
#      63 return centroids, sse
#
# File c:\Extra_folder_1\git_folder\Library-Kmars/src\kmars\kmeans_euclidean.py:104, in KMeansEuclidean._get_nearest_centroids(self, X, centroids)
#     102     datapoint = X[i]
#     103     ind_nearest_centroid = np.argmin(self._distance_euclidean(datapoint, c) for c in centroids)
# --> 104     nearest_centroids = np.append(ind_nearest_centroid, nearest_centroids, 0)
#     106 return nearest_centroids
#
# File c:\Users\jerro\anaconda3\lib\site-packages\numpy\lib\function_base.py:5617, in append(arr, values, axis)
#    5615     values = ravel(values)
#    5616     axis = arr.ndim-1
# -> 5617 return concatenate((arr, values), axis=axis)
#
# ValueError: zero-dimensional arrays cannot be concatenated
